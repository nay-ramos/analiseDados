# %% [markdown]
# <a href="https://colab.research.google.com/github/nay-ramos/analiseDados/blob/main/PowerBi/PalmerPenguinsAnalisys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Palmer Penguins Data Analisys** <font size=2>v1.1</font>
#   <code style="color:#4a304f"><font color= #d689e6>Practice</font></code>
#
# ### **Project main goals**
#
# to practice:
# - PowerBI data viz and Storytelling with Data
# - Applied Statistics
# - Documentation Process
# ---
#
# ### 🗃️ **Dataset**
#
# ><font size=2>>>> [Palmer Archipelago (Antarctica) penguin data  - Kaggle.com](https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data) by  Palmer Station, Antarctica LTER </font>
#
#
# >This dataset is originated by a reserach group in Antantica that track penguin's information at different ant Palmer Achipelogo such as mass, species (Chinstrap, Adélie or Gentoo) genre, island (Dream, Torgersen or Biscoe) etc.
#
# **Data Dictionary:** (from Kaggle)
# * Culmen length & depth:
# The culmen is "the upper ridge of a bird's beak" the culmen length and culmen
# * Date egg:
#
#
# ---
#
# ### ❓❓ **The question:**
#
# 1. Is there a relation between the penguins and the island it lives?
#
#
# ---
#
# ###  ⚙️ **Methodology:**
#   1. Collecting and analyzing Data [Kaggle]
#   2. Cleaning and Preparing
#   3. Exploratory Data analysis  [EDA]
#   4. DataViz
#   5. Insights!
#
#
# ---
#
# ### 🔨 Tools
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src="data:image/svg+xml;base64,..." width="40">
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;PowerBI

# %% [markdown]
# ### **1. Collecting and analysing Data**
#
# To start, since i know nothing about penguins, I've decided to take my time to understand the dataset a little further and be able to make an insightful analysis.
#
#
# step | description
# ----------- | -------
# **Observation** |  to take a look trough the data and info on Kaggle
# **Research** | to look for reliable sources to learn and clarify thoughts about
# **Data Dictionary** | to create a dictionary that help me and anyone to understand the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. Cleaning and Preparing**
#
# Now, understanding the data better, i can start the cleaning and preparing  process.

# %% [markdown]
# step | description
# ---- | ----
# **cleaning** | revoming unnecessary columns and duplicates
# **null treatment** | 2 lines had phisiological null info, used the species average to treat it
# **data symplification** | to numerical continuous fields: created class intervals to facilitate EDA while training statistics

# %% [markdown]
#  ### **3. Exploratory Data analysis  [EDA]**
#
# Focusing on the statistics part of this training
#
#  step | description
# ---- | ----
# **Central Tendency** | median, average and mode
# **Separation**    | quartile, percentil and removing outliers
# **Dispersion** | Standard Deviation and coefficient of variation
# .
#
# general exploration | steps
# -- | --
# **species understanding** | physical comparison
# **general graphs** | total by categories,
# **correlations** | between species and islands
# **selecting standout data** | Adélie's island comparison data

# %% [markdown]
# ### **4. Data Visualization**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To begin with, understanding the differences between penguin species is crucial for establishing the right analytical criteria. The Gentoo is the largest of the three species and possesses a short, deep bill. In contrast, Adélies and Chinstraps, while similar in body size and proportion, can be distinguished by their differing bill structures.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This perspective focuses on the distribution of species across each island. The fact that the Adélie penguin is present on all three islands raises questions about its specific adaptability and diet. This provides a unique opportunity to compare the same species under different conditions, creating a solid foundation for identifying variations. Furthermore, since the general dashboard revealed a clear distinction in proportions between males and females, it is essential to analyze both sexes separately.

# %% [markdown]
# ### **5. Insights**

# %% [markdown]
# getting back to the question: **Is there a relation between the penguins and the island it lives?** *Yes!*
#
#   * **<code style="color:#4a304f"><font color= #359292>Diet and Adaptability:</font></code>** The fact that Gentoo and Chinstrap penguins each live predominantly on a single island, while Adélie penguins are present on all three, provides insight into their respective diets and adaptability. The Gentoo's stronger, deeper bill suggests a diet of harder prey, while the similar bill shapes of Chinstrap and Adélie penguins indicate they may share comparable consumption habits.
#
# ---
#
#   * **<code style="color:#4a304f"><font color= #359292>Smallest Females on Dream Island:</font></code>** The data reveals that Dream Island is home to the smallest-bodied females. All recorded female Chinstrap penguins (the smallest species) are on Dream Island. Furthermore, 92% of female Adélie penguins residing there are in the lowest mass class (2700-3600g). This size pattern suggests an environmental factor on Dream Island, potentially related to the type or availability of food.
#
#
# ---
#
#   * **<code style="color:#4a304f"><font color= #359292>Deeper Bills in Females on Torgersen Island: </font></code>** Similar to the pattern on Dream Island, the data shows a higher prevalence of Adélie females with deeper bills on Torgersen Island. The Gentoo species (which appears to be the predominant penguin species on this island) naturally has a deeper bill than the other two species. Once again this could be diet related.
#
# ---
#
#   * **<code style="color:#4a304f"><font color= #359292>Longest Flippers in Males on Torgersen Island:</font></code>** This characteristic suggests that Adélie penguins may have specific adaptations for living on Torgersen Island. Similar to the Gentoo species, which also resides there and has long flippers, this trait could be advantageous for swimming longer distances if prey is farther from the shore compared to the other islands. Alternatively, it could be related to social dominance or mating displays. While penguin biology is not my core expertise and this remains conjectural, the data clearly shows a higher prevalence of males with longer flippers on Torgersen Island.
#
#
# ---
#
#
#
# **all rights reserved to:**
# https://github.com/allisonhorst/palmerpenguins/blob/main/README.md
